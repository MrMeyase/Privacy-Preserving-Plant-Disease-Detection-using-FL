# %%
import sys
import os

PROJECT_ROOT = r"D:\plant_fl_project"
sys.path.append(PROJECT_ROOT)

print("Added to path:", PROJECT_ROOT)

# %%
from shared.model import build_model, compile_model
from shared.config import NUM_CLASSES

model = build_model(num_classes=NUM_CLASSES)
model = compile_model(model)

model.summary()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from shared.model import build_model, compile_model
#       2 from shared.config import NUM_CLASSES
#       4 model = build_model(num_classes=NUM_CLASSES)
#
# ModuleNotFoundError: No module named 'shared'
